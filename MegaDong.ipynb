# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('Dong_Data_all.csv')
df.head()
# Out:
# C:\Users\vince\AppData\Local\Temp\ipykernel_22748\450202286.py:1: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Dong_Data_all.csv')
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1           1         FF  2022-08-13          101.2          -1.07
# 2           2         FF  2022-04-10          101.0          -2.28
# 3           3         FF  2022-05-12          100.6          -2.48
# 4           4         FF  2022-04-09          100.5          -1.44
#
#    release_pos_z      player_name  batter  pitcher    events  ... fld_score  \
# 0           5.28  Varsho, Daulton  662139   666808  home_run  ...         2
# 1           6.07       Muncy, Max  571970   672578  home_run  ...         2
# 2           5.89      Olson, Matt  621566   668881  home_run  ...         6
# 3           4.73       Soto, Juan  665742   621242  home_run  ...         4
# 4           5.10    Buxton, Byron  621439   662253  home_run  ...         2
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0                2                6               6               2
# 1               10                2              10               2
# 2                6                3               3               6
# 3                4                1               1               4
# 4                2                3               3               2
#
#    if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 0               Standard              Standard     232.0              0.114
# 1          Infield shift              Standard     215.0             -0.027
# 2          Infield shift              Standard     216.0              0.057
# 3              Strategic              Standard     228.0              0.004
# 4               Standard              Standard     234.0              0.476
#
#   delta_run_exp
# 0         2.543
# 1         1.835
# 2         0.985
# 3         1.015
# 4         1.587
#
# [5 rows x 93 columns]

# %%
# df = df[['game_date','player_name','home_team','batter','pitcher','plate_z','hc_x','hc_y','hit_distance_sc','launch_angle']]
# df.head()

# %%
df['spray_angle'] = np.tan((df['hc_x']-128)/(208-df['hc_y']))*180/np.pi*0.75

def spray_angle_cleanse(x):
    if x > 60:
        return 60
    if x < -60:
        return -60
    else:
        return x

df['spray_angle'] = df['spray_angle'].apply(lambda x: spray_angle_cleanse(x),1)
df.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1           1         FF  2022-08-13          101.2          -1.07
# 2           2         FF  2022-04-10          101.0          -2.28
# 3           3         FF  2022-05-12          100.6          -2.48
# 4           4         FF  2022-04-09          100.5          -1.44
#
#    release_pos_z      player_name  batter  pitcher    events  ...  \
# 0           5.28  Varsho, Daulton  662139   666808  home_run  ...
# 1           6.07       Muncy, Max  571970   672578  home_run  ...
# 2           5.89      Olson, Matt  621566   668881  home_run  ...
# 3           4.73       Soto, Juan  665742   621242  home_run  ...
# 4           5.10    Buxton, Byron  621439   662253  home_run  ...
#
#   post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0               2                6               6               2
# 1              10                2              10               2
# 2               6                3               3               6
# 3               4                1               1               4
# 4               2                3               3               2
#
#    if_fielding_alignment  of_fielding_alignment spin_axis delta_home_win_exp  \
# 0               Standard               Standard     232.0              0.114
# 1          Infield shift               Standard     215.0             -0.027
# 2          Infield shift               Standard     216.0              0.057
# 3              Strategic               Standard     228.0              0.004
# 4               Standard               Standard     234.0              0.476
#
#   delta_run_exp spray_angle
# 0         2.543   16.050579
# 1         1.835   20.166747
# 2         0.985   -4.065462
# 3         1.015    7.402118
# 4         1.587  -37.405066
#
# [5 rows x 94 columns]

# %%
# def section_cond(x):
#     if x <= -48:
#         return 1
#     elif x >= -47 & x <= -34:
#         return 2
#     elif x >= -33 & x <= -21:
#         return 3
#     elif x >= -20 & x <= -7:
#         return 4
#     elif x >= -6 & x <= 6:
#         return 5
#     elif x >= 7 & x <= 20:
#         return 6
#     elif x >= 21 & x <= 33:
#         return 7
#     elif x >= 34 & x <= 47:
#         return 8
#     else:
#         return 9

# df['section'] = df['spray_angle'].apply(lambda x: section_cond(x), 1)

# %%
conditions = [
    (df['spray_angle']<=-46.666),
    (df['spray_angle']<=-33.333) & (df['spray_angle']>-46.666),
    (df['spray_angle']<=-20.000) & (df['spray_angle']>-33.333),
    (df['spray_angle']<=-6.666) & (df['spray_angle']>-20.000),
    (df['spray_angle']<=6.666) & (df['spray_angle']>-6.666),
    (df['spray_angle']<=20.000) & (df['spray_angle']>6.666),
    (df['spray_angle']<=33.333) & (df['spray_angle']>20.000),
    (df['spray_angle']<=46.666) & (df['spray_angle']>33.333),
    (df['spray_angle']>46.666)]

values = [1,2,3,4,5,6,7,8,9]
df['section'] = np.select(conditions,values)
df.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1           1         FF  2022-08-13          101.2          -1.07
# 2           2         FF  2022-04-10          101.0          -2.28
# 3           3         FF  2022-05-12          100.6          -2.48
# 4           4         FF  2022-04-09          100.5          -1.44
#
#    release_pos_z      player_name  batter  pitcher    events  ...  \
# 0           5.28  Varsho, Daulton  662139   666808  home_run  ...
# 1           6.07       Muncy, Max  571970   672578  home_run  ...
# 2           5.89      Olson, Matt  621566   668881  home_run  ...
# 3           4.73       Soto, Juan  665742   621242  home_run  ...
# 4           5.10    Buxton, Byron  621439   662253  home_run  ...
#
#   post_home_score  post_bat_score  post_fld_score  if_fielding_alignment  \
# 0               6               6               2               Standard
# 1               2              10               2          Infield shift
# 2               3               3               6          Infield shift
# 3               1               1               4              Strategic
# 4               3               3               2               Standard
#
#    of_fielding_alignment  spin_axis delta_home_win_exp delta_run_exp  \
# 0               Standard      232.0              0.114         2.543
# 1               Standard      215.0             -0.027         1.835
# 2               Standard      216.0              0.057         0.985
# 3               Standard      228.0              0.004         1.015
# 4               Standard      234.0              0.476         1.587
#
#   spray_angle section
# 0   16.050579       6
# 1   20.166747       7
# 2   -4.065462       5
# 3    7.402118       6
# 4  -37.405066       2
#
# [5 rows x 95 columns]

# %%
alt = pd.read_csv('Altitude_adj.csv')
alt.head()
# Out:
#   Team  Ft above Sea Level  Adj Percent
# 0  PHI                   9          0.0
# 1  SEA                  10          0.0
# 2   SD                  13          0.0
# 3  MIA                  15          0.0
# 4  BOS                  20          0.0

# %%
df2 = pd.merge(df,alt,left_on="home_team",right_on="Team")
df2.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1          37         FF  2022-05-30           99.1          -2.16
# 2          70         FF  2022-04-10           98.4          -1.37
# 3          72         FF  2022-07-22           98.4          -1.88
# 4          92         FF  2022-04-12           98.1          -1.21
#
#    release_pos_z        player_name  batter  pitcher    events  ...  \
# 0           5.28    Varsho, Daulton  662139   666808  home_run  ...
# 1           5.59       Smith, Pavin  656976   675911  home_run  ...
# 2           6.17  Walker, Christian  572233   663158  home_run  ...
# 3           5.91    Varsho, Daulton  662139   607179  home_run  ...
# 4           5.81  Walker, Christian  572233   650556  home_run  ...
#
#   if_fielding_alignment  of_fielding_alignment  spin_axis  delta_home_win_exp  \
# 0              Standard               Standard      232.0               0.114
# 1              Standard               Standard      207.0               0.261
# 2             Strategic               Standard      215.0               0.002
# 3         Infield shift               Standard      207.0               0.012
# 4              Standard               Standard      213.0               0.194
#
#    delta_run_exp  spray_angle section Team Ft above Sea Level Adj Percent
# 0          2.543    16.050579       6   AZ               1082       -0.02
# 1          2.446    33.677651       8   AZ               1082       -0.02
# 2          0.975   -16.638460       4   AZ               1082       -0.02
# 3          0.948          NaN       0   AZ               1082       -0.02
# 4          1.000   -46.960624       1   AZ               1082       -0.02
#
# [5 rows x 98 columns]

# %%
df2['adj_hit_distance'] = df2['hit_distance_sc']+(df2['hit_distance_sc']*df2['Adj Percent'])
df2.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1          37         FF  2022-05-30           99.1          -2.16
# 2          70         FF  2022-04-10           98.4          -1.37
# 3          72         FF  2022-07-22           98.4          -1.88
# 4          92         FF  2022-04-12           98.1          -1.21
#
#    release_pos_z        player_name  batter  pitcher    events  ...  \
# 0           5.28    Varsho, Daulton  662139   666808  home_run  ...
# 1           5.59       Smith, Pavin  656976   675911  home_run  ...
# 2           6.17  Walker, Christian  572233   663158  home_run  ...
# 3           5.91    Varsho, Daulton  662139   607179  home_run  ...
# 4           5.81  Walker, Christian  572233   650556  home_run  ...
#
#   of_fielding_alignment  spin_axis  delta_home_win_exp  delta_run_exp  \
# 0              Standard      232.0               0.114          2.543
# 1              Standard      207.0               0.261          2.446
# 2              Standard      215.0               0.002          0.975
# 3              Standard      207.0               0.012          0.948
# 4              Standard      213.0               0.194          1.000
#
#    spray_angle  section Team Ft above Sea Level Adj Percent adj_hit_distance
# 0    16.050579        6   AZ               1082       -0.02           399.84
# 1    33.677651        8   AZ               1082       -0.02           408.66
# 2   -16.638460        4   AZ               1082       -0.02           424.34
# 3          NaN        0   AZ               1082       -0.02           441.98
# 4   -46.960624        1   AZ               1082       -0.02           399.84
#
# [5 rows x 99 columns]

# %%
df2['V'] = np.sqrt(df2['adj_hit_distance']/((np.sin(2*df2['launch_angle']*np.pi/180))/32.174))
df2.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1          37         FF  2022-05-30           99.1          -2.16
# 2          70         FF  2022-04-10           98.4          -1.37
# 3          72         FF  2022-07-22           98.4          -1.88
# 4          92         FF  2022-04-12           98.1          -1.21
#
#    release_pos_z        player_name  batter  pitcher    events  ... spin_axis  \
# 0           5.28    Varsho, Daulton  662139   666808  home_run  ...     232.0
# 1           5.59       Smith, Pavin  656976   675911  home_run  ...     207.0
# 2           6.17  Walker, Christian  572233   663158  home_run  ...     215.0
# 3           5.91    Varsho, Daulton  662139   607179  home_run  ...     207.0
# 4           5.81  Walker, Christian  572233   650556  home_run  ...     213.0
#
#    delta_home_win_exp  delta_run_exp  spray_angle  section  Team  \
# 0               0.114          2.543    16.050579        6    AZ
# 1               0.261          2.446    33.677651        8    AZ
# 2               0.002          0.975   -16.638460        4    AZ
# 3               0.012          0.948          NaN        0    AZ
# 4               0.194          1.000   -46.960624        1    AZ
#
#   Ft above Sea Level Adj Percent adj_hit_distance           V
# 0               1082       -0.02           399.84  121.879407
# 1               1082       -0.02           408.66  119.968855
# 2               1082       -0.02           424.34  124.348930
# 3               1082       -0.02           441.98  125.783520
# 4               1082       -0.02           399.84  127.770200
#
# [5 rows x 100 columns]

# %%
df2['Vox'] = np.cos(df2['launch_angle']/180*np.pi)*df2['V']
df2.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1          37         FF  2022-05-30           99.1          -2.16
# 2          70         FF  2022-04-10           98.4          -1.37
# 3          72         FF  2022-07-22           98.4          -1.88
# 4          92         FF  2022-04-12           98.1          -1.21
#
#    release_pos_z        player_name  batter  pitcher    events  ...  \
# 0           5.28    Varsho, Daulton  662139   666808  home_run  ...
# 1           5.59       Smith, Pavin  656976   675911  home_run  ...
# 2           6.17  Walker, Christian  572233   663158  home_run  ...
# 3           5.91    Varsho, Daulton  662139   607179  home_run  ...
# 4           5.81  Walker, Christian  572233   650556  home_run  ...
#
#   delta_home_win_exp  delta_run_exp  spray_angle  section  Team  \
# 0              0.114          2.543    16.050579        6    AZ
# 1              0.261          2.446    33.677651        8    AZ
# 2              0.002          0.975   -16.638460        4    AZ
# 3              0.012          0.948          NaN        0    AZ
# 4              0.194          1.000   -46.960624        1    AZ
#
#    Ft above Sea Level Adj Percent adj_hit_distance           V         Vox
# 0                1082       -0.02           399.84  121.879407  105.550663
# 1                1082       -0.02           408.66  119.968855  100.614348
# 2                1082       -0.02           424.34  124.348930  106.587836
# 3                1082       -0.02           441.98  125.783520  106.670475
# 4                1082       -0.02           399.84  127.770200  114.839095
#
# [5 rows x 101 columns]

# %%
df2['Voy'] = np.sin(df2['launch_angle']/180*np.pi)* df2['V']
df2.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1          37         FF  2022-05-30           99.1          -2.16
# 2          70         FF  2022-04-10           98.4          -1.37
# 3          72         FF  2022-07-22           98.4          -1.88
# 4          92         FF  2022-04-12           98.1          -1.21
#
#    release_pos_z        player_name  batter  pitcher    events  ...  \
# 0           5.28    Varsho, Daulton  662139   666808  home_run  ...
# 1           5.59       Smith, Pavin  656976   675911  home_run  ...
# 2           6.17  Walker, Christian  572233   663158  home_run  ...
# 3           5.91    Varsho, Daulton  662139   607179  home_run  ...
# 4           5.81  Walker, Christian  572233   650556  home_run  ...
#
#   delta_run_exp  spray_angle  section  Team  Ft above Sea Level  Adj Percent  \
# 0         2.543    16.050579        6    AZ                1082        -0.02
# 1         2.446    33.677651        8    AZ                1082        -0.02
# 2         0.975   -16.638460        4    AZ                1082        -0.02
# 3         0.948          NaN        0    AZ                1082        -0.02
# 4         1.000   -46.960624        1    AZ                1082        -0.02
#
#   adj_hit_distance           V         Vox        Voy
# 0           399.84  121.879407  105.550663  60.939703
# 1           408.66  119.968855  100.614348  65.339721
# 2           424.34  124.348930  106.587836  64.044433
# 3           441.98  125.783520  106.670475  66.655110
# 4           399.84  127.770200  114.839095  56.010769
#
# [5 rows x 102 columns]

# %%
dim = pd.read_csv('park_dim.csv')
dim.head()
# Out:
#    Section  Distance Distance - Field  Height Height - Field
# 0        1       355          Wrigley      37         Fenway
# 1        2       371         PNC Park      37         Fenway
# 2        3       406      Coors Field      37         Fenway
# 3        4       428    Comerica Park      37         Fenway
# 4        5       420    Comerica Park      25          Chase

# %%
df3 = pd.merge(df2,dim,left_on="section",right_on="Section")
df3.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1         770         SI  2022-08-05           94.9          -2.39
# 2         978         SI  2022-09-13           94.4          -1.42
# 3        1033         FF  2022-09-03           94.3          -1.41
# 4        1577         FF  2022-05-30           93.1          -2.92
#
#    release_pos_z       player_name  batter  pitcher    events  ...  \
# 0           5.28   Varsho, Daulton  662139   666808  home_run  ...
# 1           5.97   Varsho, Daulton  662139   608566  home_run  ...
# 2           5.54  Freeman, Freddie  518692   518876  home_run  ...
# 3           5.37     Tellez, Rowdy  642133   453178  home_run  ...
# 4           6.02     Riley, Austin  663586   668678  home_run  ...
#
#   Adj Percent  adj_hit_distance           V         Vox        Voy  Section  \
# 0       -0.02            399.84  121.879407  105.550663  60.939703        6
# 1       -0.02            414.54  126.837783  111.991115  59.546732        6
# 2       -0.02            433.16  123.512701  103.586467  67.269838        6
# 3       -0.02            419.44  126.147082  110.330724  61.157319        6
# 4       -0.02            393.96  114.830637   91.707824  69.106803        6
#
#   Distance Distance - Field Height Height - Field
# 0      428    Comerica Park     25          Chase
# 1      428    Comerica Park     25          Chase
# 2      428    Comerica Park     25          Chase
# 3      428    Comerica Park     25          Chase
# 4      428    Comerica Park     25          Chase
#
# [5 rows x 107 columns]

# %%
df3 = df3.drop(columns=["Section","Distance - Field","Height - Field"])
df3.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1         770         SI  2022-08-05           94.9          -2.39
# 2         978         SI  2022-09-13           94.4          -1.42
# 3        1033         FF  2022-09-03           94.3          -1.41
# 4        1577         FF  2022-05-30           93.1          -2.92
#
#    release_pos_z       player_name  batter  pitcher    events  ... section  \
# 0           5.28   Varsho, Daulton  662139   666808  home_run  ...       6
# 1           5.97   Varsho, Daulton  662139   608566  home_run  ...       6
# 2           5.54  Freeman, Freddie  518692   518876  home_run  ...       6
# 3           5.37     Tellez, Rowdy  642133   453178  home_run  ...       6
# 4           6.02     Riley, Austin  663586   668678  home_run  ...       6
#
#    Team  Ft above Sea Level  Adj Percent  adj_hit_distance           V  \
# 0    AZ                1082        -0.02            399.84  121.879407
# 1    AZ                1082        -0.02            414.54  126.837783
# 2    AZ                1082        -0.02            433.16  123.512701
# 3    AZ                1082        -0.02            419.44  126.147082
# 4    AZ                1082        -0.02            393.96  114.830637
#
#           Vox        Voy Distance Height
# 0  105.550663  60.939703      428     25
# 1  111.991115  59.546732      428     25
# 2  103.586467  67.269838      428     25
# 3  110.330724  61.157319      428     25
# 4   91.707824  69.106803      428     25
#
# [5 rows x 104 columns]

# %%
df3['t'] = df3['Distance']/df3['Vox']
df3.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1         770         SI  2022-08-05           94.9          -2.39
# 2         978         SI  2022-09-13           94.4          -1.42
# 3        1033         FF  2022-09-03           94.3          -1.41
# 4        1577         FF  2022-05-30           93.1          -2.92
#
#    release_pos_z       player_name  batter  pitcher    events  ... Team  \
# 0           5.28   Varsho, Daulton  662139   666808  home_run  ...   AZ
# 1           5.97   Varsho, Daulton  662139   608566  home_run  ...   AZ
# 2           5.54  Freeman, Freddie  518692   518876  home_run  ...   AZ
# 3           5.37     Tellez, Rowdy  642133   453178  home_run  ...   AZ
# 4           6.02     Riley, Austin  663586   668678  home_run  ...   AZ
#
#    Ft above Sea Level  Adj Percent  adj_hit_distance           V         Vox  \
# 0                1082        -0.02            399.84  121.879407  105.550663
# 1                1082        -0.02            414.54  126.837783  111.991115
# 2                1082        -0.02            433.16  123.512701  103.586467
# 3                1082        -0.02            419.44  126.147082  110.330724
# 4                1082        -0.02            393.96  114.830637   91.707824
#
#          Voy Distance Height         t
# 0  60.939703      428     25  4.054925
# 1  59.546732      428     25  3.821732
# 2  67.269838      428     25  4.131814
# 3  61.157319      428     25  3.879246
# 4  69.106803      428     25  4.666995
#
# [5 rows x 105 columns]

# %%
df3['height_t'] = df3['plate_z']+(df3['Voy']*df3['t'])+0.5*(-32.174)*(df3['t']*df3['t'])
df3.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1         770         SI  2022-08-05           94.9          -2.39
# 2         978         SI  2022-09-13           94.4          -1.42
# 3        1033         FF  2022-09-03           94.3          -1.41
# 4        1577         FF  2022-05-30           93.1          -2.92
#
#    release_pos_z       player_name  batter  pitcher    events  ...  \
# 0           5.28   Varsho, Daulton  662139   666808  home_run  ...
# 1           5.97   Varsho, Daulton  662139   608566  home_run  ...
# 2           5.54  Freeman, Freddie  518692   518876  home_run  ...
# 3           5.37     Tellez, Rowdy  642133   453178  home_run  ...
# 4           6.02     Riley, Austin  663586   668678  home_run  ...
#
#   Ft above Sea Level  Adj Percent  adj_hit_distance           V         Vox  \
# 0               1082        -0.02            399.84  121.879407  105.550663
# 1               1082        -0.02            414.54  126.837783  111.991115
# 2               1082        -0.02            433.16  123.512701  103.586467
# 3               1082        -0.02            419.44  126.147082  110.330724
# 4               1082        -0.02            393.96  114.830637   91.707824
#
#          Voy Distance Height         t   height_t
# 0  60.939703      428     25  4.054925 -14.503218
# 1  59.546732      428     25  3.821732  -5.729189
# 2  67.269838      428     25  4.131814   5.271025
# 3  61.157319      428     25  3.879246  -1.751720
# 4  69.106803      428     25  4.666995 -25.817345
#
# [5 rows x 106 columns]

# %%
df3.loc[df3['height_t'] <= df3['Height'], 'mega_dong'] = 0
df3.loc[df3['height_t'] > df3['Height'], 'mega_dong'] = 1
df3.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-07-05          101.8          -2.07
# 1         770         SI  2022-08-05           94.9          -2.39
# 2         978         SI  2022-09-13           94.4          -1.42
# 3        1033         FF  2022-09-03           94.3          -1.41
# 4        1577         FF  2022-05-30           93.1          -2.92
#
#    release_pos_z       player_name  batter  pitcher    events  ...  \
# 0           5.28   Varsho, Daulton  662139   666808  home_run  ...
# 1           5.97   Varsho, Daulton  662139   608566  home_run  ...
# 2           5.54  Freeman, Freddie  518692   518876  home_run  ...
# 3           5.37     Tellez, Rowdy  642133   453178  home_run  ...
# 4           6.02     Riley, Austin  663586   668678  home_run  ...
#
#   Adj Percent  adj_hit_distance           V         Vox        Voy  Distance  \
# 0       -0.02            399.84  121.879407  105.550663  60.939703       428
# 1       -0.02            414.54  126.837783  111.991115  59.546732       428
# 2       -0.02            433.16  123.512701  103.586467  67.269838       428
# 3       -0.02            419.44  126.147082  110.330724  61.157319       428
# 4       -0.02            393.96  114.830637   91.707824  69.106803       428
#
#   Height         t   height_t mega_dong
# 0     25  4.054925 -14.503218       0.0
# 1     25  3.821732  -5.729189       0.0
# 2     25  4.131814   5.271025       0.0
# 3     25  3.879246  -1.751720       0.0
# 4     25  4.666995 -25.817345       0.0
#
# [5 rows x 107 columns]

# %%
# df3.to_csv('python_export.csv')

# %%
# df_group = df3.groupby('section').agg(Sum=('mega_dong',np.sum), Total=('mega_dong','count'))
# df_group['Percentage'] = (round((df_group['Sum'] / df_group['Total'])*100,2)).astype(str)+'%'

# df_group

# %%
# df_group.to_csv('Dong Data - Player Sum.csv')

# %%
# judge_mega = df3[df3["player_name"] == "Judge, Aaron"]
# judge_mega

# %%
df3['bases_loaded'] = df3[['on_1b','on_2b','on_3b']].min(axis=1)

# %%
df3.loc[df3['bases_loaded'] >0, 'grand_slam'] = 1
df3.loc[df3['bases_loaded']==0, 'grand_slam'] = 0
df3.loc[df3['bases_loaded']=='NaN', 'grand_slam'] = 0

# %%
df3['spray_angle_adj'] = df3['spray_angle']/60*45

# %%
df3['spray_angle_adj'].max()
# Out:
# 45.0
